# %%
#Description: This program gets the price of cryptocurrency in Real time

# %%
#Import the Libraries
from bs4 import BeautifulSoup
import requests
import time

# %%
#Get the Url for example
#https://www.google.com/search?sxsrf=ALeKk00yhgM6plDa0rQGqMYQqvedzFJiqw%3A1614184752271&ei=MIE2YMaBEPzez7sPqqmiuA0&q=litecoin+price&oq=litecoin+price&gs_lcp=Cgdnd3Mtd2l6EAMyBwgAELEDEEMyDQgAEIcCELEDEIMBEBQyBAgAEEMyCAgAELEDEIMBMgcIABCxAxBDMgIIADICCAAyAggAMgIIADIICAAQBxAKEB46BwgjELADECc6BwgAELADEEM6BggAEAcQHjoHCCMQsQIQJ1DM6QJYofcCYJ6CA2gFcAJ4AIAB_wKIAd4PkgEFMi03LjGYAQCgAQGqAQdnd3Mtd2l6yAEKwAEB&sclient=gws-wiz&ved=0ahUKEwjG2Yrm-oLvAhV873MBHaqUCNcQ4dUDCA0&uact=5
url = 'https://www.google.com/search?q=bitcoin+price&oq=bitcoi&aqs=chrome.0.69i59j0i131i433j69i57j0i20i131i263i433j0i67i433j0i131i433l5.2286j0j15&sourceid=chrome&ie=UTF-8'

#Make a request to the website
HTML = requests.get(url)

#Parse the HTML
soup = BeautifulSoup(HTML.text, 'html.parser')

#print soup to find where the text is that contains the price of the cryptocurrency
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>
#   <title>
#    bitcoin price - Google Search
#   </title>
#   <script nonce="sLzrm7hJz8xEMOQinTeCGA==">
#    (function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName){a="1"==a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# ...

# %%
#Create a function to get the price of a cryptocurrency
def get_crypto_price(coin):
  #Get the Url for example
  #https://www.google.com/search?sxsrf=ALeKk00yhgM6plDa0rQGqMYQqvedzFJiqw%3A1614184752271&ei=MIE2YMaBEPzez7sPqqmiuA0&q=litecoin+price&oq=litecoin+price&gs_lcp=Cgdnd3Mtd2l6EAMyBwgAELEDEEMyDQgAEIcCELEDEIMBEBQyBAgAEEMyCAgAELEDEIMBMgcIABCxAxBDMgIIADICCAAyAggAMgIIADIICAAQBxAKEB46BwgjELADECc6BwgAELADEEM6BggAEAcQHjoHCCMQsQIQJ1DM6QJYofcCYJ6CA2gFcAJ4AIAB_wKIAd4PkgEFMi03LjGYAQCgAQGqAQdnd3Mtd2l6yAEKwAEB&sclient=gws-wiz&ved=0ahUKEwjG2Yrm-oLvAhV873MBHaqUCNcQ4dUDCA0&uact=5
  url = 'https://www.google.com/search?q='+coin+'+price&oq=bitcoi&aqs=chrome.0.69i59j0i131i433j69i57j0i20i131i263i433j0i67i433j0i131i433l5.2286j0j15&sourceid=chrome&ie=UTF-8'

  #Make a request to the website
  HTML = requests.get(url)

  #Parse the HTML
  soup = BeautifulSoup(HTML.text, 'html.parser')

  #Find the current price

  # <div class="BNeawe tAd8D AP7Wnd">

  text = soup.find('div', attrs={'class': 'BNeawe iBp4i AP7Wnd'}).find('div', attrs={'class':'BNeawe iBp4i AP7Wnd'}).text

  # Return the text
  return text

# %%
#Get the price of the cryptocurrency
price = get_crypto_price('litecoin')

#Print the Price
print(price)
# Out:
# 181.72 United States Dollar

# %%
#Create a function to conssitantly show the price of the cryptocurrency when it changes
def main():
  last_price = -1
  #Create a loop to continously show the price
  while True:
    #Choose the Cryptocurrency that I want to get the price for
    crypto = 'litecoin'
    #get the price of the Cryptocurrency
    price = get_crypto_price(crypto)
    #Check if the price changed
    if price != last_price:
      print(crypto+' price: ', price)
      last_price = price
    time.sleep(3)

# %%
#Run/Execute the main function
main()
# Out:
# litecoin price:  182.69 United States Dollar
# litecoin price:  183.38 United States Dollar
# litecoin price:  183.60 United States Dollar
# litecoin price:  183.03 United States Dollar
